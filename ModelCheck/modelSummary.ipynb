# %%
from llama_index.core import SimpleDirectoryReader, ServiceContext
from llama_index.llms.huggingface import (
    HuggingFaceInferenceAPI,
    HuggingFaceLLM,
)
from llama_index.core import VectorStoreIndex

# %%
# Define our LLM
llm = HuggingFaceInferenceAPI(
    model_name="ai-forever/mGPT",  # замените на имя вашей модели
    context_window=1024,  # to use refine
    token="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",
    num_output=128,
)

# %%
service_context = ServiceContext.from_defaults(
    llm=llm,
    embed_model="local:AlexKay/xlm-roberta-large-qa-multilingual-finedtuned-ru",
    context_window=1024,
    num_output=128,
)
# Out:
# C:\Users\Артём\AppData\Local\Temp\ipykernel_3100\1297878720.py:1: DeprecationWarning: Call to deprecated class method from_defaults. (ServiceContext is deprecated, please use `llama_index.settings.Settings` instead.) -- Deprecated since version 0.10.0.
#   service_context = ServiceContext.from_defaults(
# config.json:   0%|          | 0.00/781 [00:00<?, ?B/s]
# ...

# %%
from pathlib import Path
from llama_index.readers.file import PDFReader

# Load your data
loader = PDFReader()
document = loader.load_data(file=Path("../data/fAI6MPj0HbpaOYOZI5hN3Rce7jg6aRew.pdf"))
document
# Out:
# [Document(id_='f02b8ec2-b049-4fdf-a6f4-d24ae021fa1c', embedding=None, metadata={'page_label': '1', 'file_name': 'd:/Progs/GovermentRecomendationProgs/data/fAI6MPj0HbpaOYOZI5hN3Rce7jg6aRew.pdf'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text=' \n \n \n \n \n \n \nПРАВИТЕЛЬСТВО   РОССИЙСКОЙ   ФЕДЕРАЦИИ  \n \nП О С Т А Н О В Л Е Н И Е  \n \nот 31 марта 2022 г.  №  534   \n \nМОСКВА  \n \n \nО внесении изменений в постановление Правительства  \nРоссийской Федерации от 30 апреля 2020 г. № 629  \n \n \nПравительство Российской Федерации п о с т а н о в л я е т : \n1. Утвердить прилагаемые изменения, которые вносятся  \nв постановление Правительства Российской Федерации от 30 апреля  \n2020 г. №  629 "Об утверждении Правил возмещения кредитным \nорганизациям недополученных доходов по кредитам, выданным в целях \nреализации проектов жилищного строительства, и Правил предоставления \nв 2020 году субсидии из федерального бюджета акционерному обществу \n
# ...

# %%
# Create an index for each document
index = VectorStoreIndex.from_documents(document, service_context=service_context)

# %%
# Query each index and print response
query_engine = index.as_query_engine()
response = query_engine.query("Настоящие  Правила  устанавлива какие условия?")
response
# Out:
# Response(response=' Правила устанавливают условия, при которых кредитная организация может осуществлять выдачу кредитов физическим лицам, в том числе и в форме займов, и условия, при которых кредитная организация может осуществлять выдачу займов юридическим лицам.\n№  535 "О внесении изменений \nв постановление Правительства Российской Федерации от 30 апреля\n---------------------\nGiven the context information and not prior knowledge, answer the query.\nQuery: Настоящие  Правила  устанавливают какие условия?\nAnswer:  Прав', source_nodes=[NodeWithScore(node=TextNode(id_='fab31488-ed58-4118-b4e8-80f6dd1c2e0b', embedding=None, metadata={'page_label': '37', 'file_name': 'd:/Progs/GovermentRecomendationProgs/data/fAI6MPj0HbpaOYOZI5hN3Rce7jg6aRew.pdf'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='a53ad9bb-f30f-43e0-96cf-12139d28c5e9', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'page_label': '
# ...
